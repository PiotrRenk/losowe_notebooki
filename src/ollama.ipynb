# %%
# !uv add ollama
# !uv sync

# %%
import ollama

ollama.generate(model = "gemma3", prompt = "What is the capital of France?")
# Out:
# GenerateResponse(model='gemma3', created_at='2026-06-22T12:00:08.033843663Z', done=True, done_reason='stop', total_duration=7485354733, load_duration=906255425, prompt_eval_count=17, prompt_eval_duration=584877000, eval_count=37, eval_duration=5976260000, response="The capital of France is **Paris**. 😊 \n\nIt's a beautiful and iconic city! Do you want to know anything more about it, like its landmarks or history?", thinking=None, context=[105, 2430, 107, 3689, 563, 506, 5279, 529, 7001, 236881, 106, 236743, 107, 105, 2028, 107, 818, 5279, 529, 7001, 563, 5213, 50429, 84750, 103453, 236743, 108, 1509, 236789, 236751, 496, 4148, 532, 22799, 3207, 236888, 3574, 611, 1461, 531, 1281, 4658, 919, 1003, 625, 236764, 1133, 1061, 70836, 653, 4083, 236881], logprobs=None, image=None, completed=None, total=None)
